# %% [markdown]
# ## The main factors which impacts the house price in Kansas City

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import mpl_toolkits
# %matplotlib inline

# %%
data = pd.read_csv("./kc_house_data.csv")

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.corr().style.background_gradient().format('{:.2f}')
# Out:
# <style type="text/css">
# #T_02c2e_row0_col0, #T_02c2e_row1_col1, #T_02c2e_row2_col2, #T_02c2e_row3_col3, #T_02c2e_row4_col4, #T_02c2e_row5_col5, #T_02c2e_row6_col6, #T_02c2e_row7_col7, #T_02c2e_row8_col8, #T_02c2e_row9_col9, #T_02c2e_row10_col10, #T_02c2e_row11_col11, #T_02c2e_row12_col12, #T_02c2e_row13_col13, #T_02c2e_row14_col14, #T_02c2e_row15_col15, #T_02c2e_row16_col16, #T_02c2e_row17_col17, #T_02c2e_row18_col18, #T_02c2e_row19_col19 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_02c2e_row0_col1, #T_02c2e_row2_col7, #T_02c2e_row9_col10 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_02c2e_row0_col2, #T_02c2e_row5_col1, #T_02c2e_row7_col5, #T_02c2e_row8_col16, #T_02c2e_row9_col14, #T_02c2e_row14_col19 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_02c2e_row0_col3, #T_02c2e_row3_col9, #T_02c2e_row4_col16, #T_02c2e_row6_col16 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# ...

# %%
snsplot = sns.jointplot(x = "lat", y = "long", kind="scatter", data=data)

# %%
x = data['sqft_living']
y = data['price']
house_avg_price = round(y.mean(), 20)
size = y / house_avg_price * 20
plt.figure(figsize=(20, 10))
plt.title('The relationship between the house living area and the house price')
fig = plt.scatter(x,y, s=size, alpha=0.5, label='house living area compared to the average house living area in KC')
# maximum likelihood estimation
x = sm.add_constant(x)
model = sm.OLS(y, x).fit()
predicts = model.predict()
x = data['sqft_living']
plt.plot(x, predicts, color='red', label='maximum likelihood estimation')

# legend
plt.legend(loc='upper left')
plt.xlabel('house living area')
plt.ylabel('price')

plt.show()

# %%
x = data['sqft_lot']
y = data['price']
house_avg_price = round(y.mean(), 20)
size = y / house_avg_price * 20
plt.figure(figsize=(20, 10))
plt.title('The relationship between the house lot area and the house price')
fig = plt.scatter(x, y, s=size, alpha=0.5)
plt.legend(handles = [fig],labels=['house lot area compared to the average house lot area in KC'],loc='best')

plt.xlabel('house lot area')
plt.ylabel('price')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.scatter(data.price, data.long)
plt.title("Price vs Location of the area")
# Out:
# Text(0.5, 1.0, 'Price vs Location of the area')

# %%
plt.figure(figsize=(20, 10))
plt.scatter(data.bedrooms,data.price)
plt.title("Bedroom and Price ")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.scatter(data.yr_built,data.price)
plt.title("year built and Price ")
plt.xlabel("Year")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.scatter(data.yr_renovated,data.price)
plt.title("year renovated and Price ")
plt.xlabel("Year")
plt.ylabel("Price")
plt.show()
